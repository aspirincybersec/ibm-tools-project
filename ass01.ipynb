# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# SANTHOSH

# %% [markdown]
# # I am interested in data sciehhhnce because i love data

# %% [markdown]
# ### print hi

# %%
print("hi")
# Out:
# hi

# %% [markdown]
# #### done
